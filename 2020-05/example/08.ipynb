# %%
# %matplotlib inline
import pandas as pd
import xlwings as xw

# %%
df = pd.read_excel('data/2016-01.xls', index_col='상품명')
print(df.shape)
df.head()
# Out:
# (200, 3)
#        판매건수     가격        매출
# 상품명
# 봉투    12362     50    618100
# 바나나    4285   3900  16711500
# 야채     4190      0         0
# 켐벨포도   2780  29800  82844000
# 알뜰특란   2768   5300  14670400

# %%
판매건수_top10 = df.sort_values('판매건수', ascending=False).head(10)
판매건수_top10
# Out:
#         판매건수     가격        매출
# 상품명
# 봉투     12362     50    618100
# 바나나     4285   3900  16711500
# 야채      4190      0         0
# 켐벨포도    2780  29800  82844000
# 알뜰특란    2768   5300  14670400
# 딸기      2234      0         0
# 팔음산포도   2161  19800  42787800
# 봉투      2038     30     61140
# 애호박     1962   1490   2923380
# 청양고추    1901      0         0

# %%
판매건수_top10.plot(kind='bar')

# %%
판매건수_top10[['판매건수', '가격']].plot(kind='bar')

# %%
from matplotlib import rc
rc('font', family='Malgun Gothic')
# rc('font', family='AppleGothic')

# %%
from matplotlib import font_manager
font_manager.fontManager.ttflist
# Out:
# t 'SimSun' (simsun.ttc) normal normal 400 normal>,
#  <Font 'Calisto MT' (CALISTBI.TTF) italic normal bold normal>,
#  <Font 'Comic Sans MS' (comicbd.ttf) normal normal bold normal>,
#  <Font 'Elephant' (ELEPHNT.TTF) normal normal 400 normal>,
#  <Font 'Calibri' (calibrib.ttf) normal normal bold normal>,
#  <Font 'Courier New' (courbi.ttf) italic normal bold normal>,
#  <Font 'Californian FB' (CALIFB.TTF) normal normal bold normal>,
#  <Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>,
#  <Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal bold normal>,
#  <Font 'Onyx' (ONYX.TTF) normal normal 400 normal>,
#  <Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>,
#  <Font 'HYPost-Light' (H2PORL.TTF) normal normal light normal>,
#  <Font 'LG Smart_H' (LGSmHaR_v1.4_151215.ttf) normal normal regular normal>,
#  <Font 'Segoe UI' (segoeuiz.ttf) italic normal bold normal>,
#  <Font 'Showcard Gothic' (SHOWG.TTF) normal normal 400 normal>,
# ...

# %%
판매건수_top10[['판매건수', '가격']].plot(kind='barh')

# %%
판매건수_top10[['판매건수', '가격']].sort_values('가격').plot(kind='barh')

# %%
판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='bar')

# %%
판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-000bfbd4ec6e> in <module>
# ----> 1 판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='pie')
#
# D:\Work\Dev\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     797                 if y is None and kwargs.get("subplots") is False:
#     798                     raise ValueError(
# --> 799                         f"{kind} requires either y column or 'subplots=True'"
#     800                     )
#     801                 elif y is not None:
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='pie', y='판매건수')

# %%
판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='pie', y='가격')

# %%
df
# Out:
#                     판매건수     가격        매출
# 상품명
# 봉투                 12362     50    618100
# 바나나                 4285   3900  16711500
# 야채                  4190      0         0
# 켐벨포도                2780  29800  82844000
# 알뜰특란                2768   5300  14670400
# ...                  ...    ...       ...
# 바지락                  253      0         0
# 해표)카놀라유              253   5600   1416800
# 오)자른당면               252   5850   1474200
# 롯데)알뜰소시지             252   4400   1108800
# 한돈앞다리/불고기,찌개(국내산)    252      0         0
#
# [200 rows x 3 columns]

# %%
xw.view(df)

# %%
판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='barh')

# %%
xw.view(판매건수_top10, xw.sheets.active)

# %%
ax = 판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='barh')

# %%
fig = ax.get_figure()
fig

# %%
sheet = xw.sheets.active

# %%
left = sheet.range('F1').left
top = sheet.range('F1').top
sheet.pictures.add(fig, name='2016년 1월 판매량 TOP 10', update=True, left=left, top=top)
# Out:
# <Picture '2016년 1월 판매량 TOP 10' in <Sheet [통합 문서1]Sheet1>>

# %%
ax = 판매건수_top10[['판매건수', '가격']].sort_values('가격', ascending=False).plot(kind='bar', grid=True, figsize=(8, 3), rot=0)

# %%
fig = ax.get_figure()
fig

# %%
sheet.pictures.add(fig, name='2016년 1월 판매량 TOP 10', update=True, left=left, top=top)
# Out:
# <Picture '2016년 1월 판매량 TOP 10' in <Sheet [통합 문서1]Sheet1>>
